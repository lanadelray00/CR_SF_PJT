# %%
#!/usr/bin/env python3

import rclpy
import numpy as np
from robot_interface_client import RobotInterfaceClient


def main():
    rclpy.init()
    robot = RobotInterfaceClient()

    print("⏳ Waiting for FK data...")

    try:
        while rclpy.ok():
            rclpy.spin_once(robot, timeout_sec=0.1)

            orient = robot.current_orientation
            if orient is not None:
                break

        print("\n===== FK Orientation Check =====")
        print("orient value:", orient)
        print("length:", len(orient))
        print("norm:", np.linalg.norm(orient))

        if len(orient) == 4:
            print("✅ Quaternion (x, y, z, w)")
        elif len(orient) == 3:
            print("⚠ Euler angles (roll, pitch, yaw)")
        else:
            print("❌ Unknown orientation format")

    finally:
        rclpy.shutdown()


if __name__ == "__main__":
    main()
# Out:
# [INFO] [1767344229.701714782] [robot_interface_client]: 🧪 robot_interface_client Node initialized
# [INFO] [1767344229.703613459] [robot_interface_client]: ⏳ Waiting for all service servers...
# ⏳ Waiting for FK data...
#
# ===== FK Orientation Check =====
# orient value: [np.float64(5.551115123125783e-17), np.float64(0.441050575281686), np.float64(0.5325513676355642)]
# length: 3
# norm: 0.6914741998996174
# ⚠ Euler angles (roll, pitch, yaw)
# [INFO] [1767344230.455002858] [robot_interface_client]: ✅ All service servers available.
